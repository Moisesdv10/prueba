# %% [markdown]
# #Nombres:
#
# 1.   Leidy Melissa Marín Fajardo___        2251490
# 2.   Moisés David Villalba Contreras___    2251489

# %% [markdown]
# #1.Importar librerias

# %%
import pandas as pd
import io
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #2.Importar el dataset

# %%
from google.colab import files 
datos=files.upload()
# Out:
#      <input type="file" id="files-c1a62b75-2acb-4f65-9cf3-d3b4543bbe2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1a62b75-2acb-4f65-9cf3-d3b4543bbe2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BankCustomerData.csv to BankCustomerData.csv

# %% [markdown]
# #3.Visualizar el dataset

# %%
data_bank=pd.read_csv(io.BytesIO(datos['BankCustomerData.csv']))
data_bank
# Out:
#        age           job  marital  ... previous poutcome  term_deposit
# 0       58    management  married  ...        0  unknown            no
# 1       44    technician   single  ...        0  unknown            no
# 2       33  entrepreneur  married  ...        0  unknown            no
# 3       47   blue-collar  married  ...        0  unknown            no
# 4       33       unknown   single  ...        0  unknown            no
# ...    ...           ...      ...  ...      ...      ...           ...
# 42634   21       student   single  ...        1  success           yes
# 42635   87       retired  married  ...        0  unknown           yes
# 42636   34   blue-collar  married  ...        1    other            no
# 42637   22       student   single  ...        0  unknown           yes
# 42638   32    management   single  ...        0  unknown            no
#
# [42639 rows x 17 columns]

# %% [markdown]
# #4.Entender datos

# %%
data_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42639 entries, 0 to 42638
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           42639 non-null  int64
#  1   job           42639 non-null  object
#  2   marital       42639 non-null  object
#  3   education     42639 non-null  object
#  4   default       42639 non-null  object
#  5   balance       42639 non-null  int64
#  6   housing       42639 non-null  object
#  7   loan          42639 non-null  object
#  8   contact       42639 non-null  object
#  9   day           42639 non-null  int64
#  10  month         42639 non-null  object
#  11  duration      42639 non-null  int64
#  12  campaign      42639 non-null  int64
#  13  pdays         42639 non-null  int64
#  14  previous      42639 non-null  int64
#  15  poutcome      42639 non-null  object
#  16  term_deposit  42639 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.5+ MB

# %%
data_bank.describe()
# Out:
#                 age        balance  ...         pdays      previous
# count  42639.000000   42639.000000  ...  42639.000000  42639.000000
# mean      40.788808    1331.863951  ...     34.169141      0.465442
# std       10.200236    3011.537676  ...     92.041713      2.166705
# min       18.000000   -8019.000000  ...     -1.000000      0.000000
# 25%       33.000000      62.000000  ...     -1.000000      0.000000
# 50%       39.000000     429.000000  ...     -1.000000      0.000000
# 75%       48.000000    1381.500000  ...     -1.000000      0.000000
# max       95.000000  102127.000000  ...    536.000000    275.000000
#
# [8 rows x 7 columns]

# %%
data_bank.isna().sum()
# Out:
# age             0
# job             0
# marital         0
# education       0
# default         0
# balance         0
# housing         0
# loan            0
# contact         0
# day             0
# month           0
# duration        0
# campaign        0
# pdays           0
# previous        0
# poutcome        0
# term_deposit    0
# dtype: int64

# %% [markdown]
# #5.Limpieza y preparación de datos

# %% [markdown]
# ##5.1.Variable Job

# %%
data_bank['job'].unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
job_bank={"job": {'management':1, 
                  'technician':2,
                  'entrepreneur':3,
                  'blue-collar':4,
                  'unknown':5,
                  'retired':6,
                  'admin.':7,
                  'services':8,
                  'self-employed':9,
                  'unemployed':10,
                  'housemaid':11,
                  'student':12}}
data_bank.replace(job_bank, inplace=True)

# %% [markdown]
# ##5.2.Variable Marital

# %%
data_bank['marital'].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
marital_bank={"marital": {'married':1, 
                  'single':2,
                  'divorced':3}}
data_bank.replace(marital_bank, inplace=True)

# %% [markdown]
# ##5.3.Variable Education

# %%
data_bank['education'].unique()
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
education_bank={"education": {'tertiary':1, 
                  'secondary':2,
                  'unknown':3,
                  'primary':4}}
data_bank.replace(education_bank, inplace=True)

# %% [markdown]
# ##5.4.Variable Default

# %%
data_bank['default'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
default_bank={"default": {'no':1, 
                  'yes':2}}
data_bank.replace(default_bank, inplace=True)

# %% [markdown]
# ##5.5.Variable Housing

# %%
data_bank['housing'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
housing_bank={"housing": {'yes':1, 
                  'no':2}}
data_bank.replace(housing_bank, inplace=True)

# %% [markdown]
# ##5.6.Variable Loan

# %%
data_bank['loan'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
loan_bank={"loan": {'no':1, 
                  'yes':2}}
data_bank.replace(loan_bank, inplace=True)

# %% [markdown]
# ##5.7.Variable Contact

# %%
data_bank['contact'].unique()
# Out:
# array(['unknown', 'cellular', 'telephone'], dtype=object)

# %%
contact_bank={"contact": {'unknown':0, 
                  'cellular':1,
                  'telephone':2}}
data_bank.replace(contact_bank, inplace=True)

# %% [markdown]
# ##5.8.Variable Month

# %%
data_bank['month'].unique()
# Out:
# array(['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec', 'jan', 'feb',
#        'mar', 'apr', 'sep'], dtype=object)

# %%
month_bank={"month": {'may':5, 
                  'jun':6,
                  'jul':7,
                  'aug':8,
                  'oct':10,
                  'nov':11,
                  'dec':12,
                  'jan':1,
                  'feb':2,
                  'mar':3,
                  'apr':4,
                  'sep':9}}
data_bank.replace(month_bank, inplace=True)

# %% [markdown]
# ##5.9.Variable Poutcome

# %%
data_bank['poutcome'].unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %%
poutcome_bank={"poutcome": {'unknown':0, 
                  'failure':1,
                  'other':2,
                  'success':3}}
data_bank.replace(poutcome_bank, inplace=True)

# %% [markdown]
# ##5.10.Variable Term Deposit

# %%
data_bank['term_deposit'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
deposit_bank={"term_deposit": {'no':1, 
                  'yes':2}}
data_bank.replace(deposit_bank, inplace=True)

# %% [markdown]
# ##5.11.Verificar que la limpieza de datos haya sido exitosa

# %%
data_bank.head()
# Out:
#    age  job  marital  education  ...  pdays  previous  poutcome  term_deposit
# 0   58    1        1          1  ...     -1         0         0             1
# 1   44    2        2          2  ...     -1         0         0             1
# 2   33    3        1          2  ...     -1         0         0             1
# 3   47    4        1          3  ...     -1         0         0             1
# 4   33    5        2          3  ...     -1         0         0             1
#
# [5 rows x 17 columns]

# %%
data_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42639 entries, 0 to 42638
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           42639 non-null  int64
#  1   job           42639 non-null  int64
#  2   marital       42639 non-null  int64
#  3   education     42639 non-null  int64
#  4   default       42639 non-null  int64
#  5   balance       42639 non-null  int64
#  6   housing       42639 non-null  int64
#  7   loan          42639 non-null  int64
#  8   contact       42639 non-null  int64
#  9   day           42639 non-null  int64
#  10  month         42639 non-null  int64
#  11  duration      42639 non-null  int64
#  12  campaign      42639 non-null  int64
#  13  pdays         42639 non-null  int64
#  14  previous      42639 non-null  int64
#  15  poutcome      42639 non-null  int64
#  16  term_deposit  42639 non-null  int64
# dtypes: int64(17)
# memory usage: 5.5 MB

# %% [markdown]
# #6.**Graficas**

# %% [markdown]
# ##6.1.Matriz de correlación

# %%
import seaborn as sns
correlation_matrix = data_bank.corr().round(2)
fig, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# ##6.2.Diagrama de ditribución

# %%
filas = 4
columnas = 4

fig, ax = plt.subplots(nrows=filas, ncols=columnas, figsize=(30, 30))
col = data_bank.columns
index = 0

for i in range(filas):
    for j in range(columnas):
        sns.histplot(data_bank[col[index]], ax=ax[i][j], kde=True, stat='density')
        index += 1

plt.tight_layout()

# %%
sns.histplot(data_bank['term_deposit'], kde=True, stat='density')

# %% [markdown]
# #7.Separar datos

# %%
from sklearn.model_selection import train_test_split
x= data_bank.drop(columns='term_deposit')
y=data_bank['term_deposit']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2,random_state=0)

# %% [markdown]
# #8.Modelo de regresión logistica

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
regresion=LogisticRegression()
regresion.fit(x_train,y_train)
y_pre=regresion.predict(x_test)
print("Score training: ",regresion.score(x_train,y_train)*100, "%")
print("Score test: ",regresion.score(x_test,y_test)*100, "%")
print("Accuracy: ", accuracy_score(y_test, y_pre)*100, "%")
# Out:
# Score training:  91.17879862800856 %
# Score test:  90.79502814258912 %
# Accuracy:  90.79502814258912 %
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# ##8.1.Matriz de confusion

# %%
from sklearn.metrics import confusion_matrix 
import numpy as np
cm=confusion_matrix(y_test,y_pre)
print(cm)
import seaborn as sns
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cm.flatten()/np.sum(cm)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
class_names=['Not Access','Access']
dataframe=pd.DataFrame(cm,index=class_names, columns=class_names)
sns.heatmap(dataframe, annot=True, fmt='', cmap='Blues')
# Out:
# [[7628  106]
#  [ 679  115]]

# %% [markdown]
# #9.Modelo Arbol de desicion

# %% [markdown]
# ##9.1.Conocer la profundidad adecuada

# %%
#la profundad de un árbol la medimos con max_depth
max_depth_lista = list(range(1, 15))
# creamos un listado de resultados de exactitud 
accuracy = []
for depth in max_depth_lista:
    
    modelo_arbol = DecisionTreeClassifier(max_depth = depth, random_state = 0)
    modelo_arbol.fit(x_train, y_train)
    score = modelo_arbol.score(x_test, y_test)
    accuracy.append(score)

# %%
plt.plot(max_depth_lista,accuracy)

# %% [markdown]
# ##9.2.Presiciones

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
arbol= DecisionTreeClassifier(max_depth=6,random_state=0)
arbol.fit(x_train,y_train)
y_predi=arbol.predict(x_test)

print("Accuracy: ", accuracy_score(y_test, y_predi)*100, "%")
print("Score Training: ",arbol.score(x_train,y_train)*100, "%")
print("Score Test: ",arbol.score(x_test,y_test)*100, "%")
# Out:
# Accuracy:  91.3109756097561 %
# Score Training:  92.26056110931957 %
# Score Test:  91.3109756097561 %

# %% [markdown]
# ##9.3.Importancia de las variables

# %%
importance = pd.DataFrame({'feature':x_train.columns, 'importance':np.round(arbol.feature_importances_, 3)})
importance = importance.sort_values('importance', ascending=True)
importance.head(17)
# Out:
#       feature  importance
# 9         day       0.000
# 12   campaign       0.000
# 4     default       0.001
# 14   previous       0.001
# 1         job       0.002
# 7        loan       0.002
# 3   education       0.003
# 6     housing       0.007
# 2     marital       0.008
# 13      pdays       0.018
# 5     balance       0.022
# 8     contact       0.040
# 0         age       0.045
# 10      month       0.056
# 15   poutcome       0.115
# 11   duration       0.680

# %% [markdown]
# ##9.4.Árbol generado

# %%
# Graficando el árbol de decisiones
from sklearn import tree

fig,ax=plt.subplots(figsize=(95,9))

print(f"Profundidad del árbol: {arbol.get_depth()}")
print(f"Número de nodos terminales: {arbol.get_n_leaves()}")

tree=tree.plot_tree(
    decision_tree=arbol,
    feature_names=data_bank.drop(columns="term_deposit").columns,
    class_names='Term Deposit',
    filled=True,
    impurity=False,
    fontsize=10,
    precision=2,
    ax=ax
)
# Out:
# Profundidad del árbol: 6
# Número de nodos terminales: 61

# %% [markdown]
# ##9.5.Matriz de confusión

# %%
from sklearn.metrics import confusion_matrix 
import numpy as np
matriz=confusion_matrix(y_test,y_predi)
print(matriz)
import seaborn as sns
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in matriz.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in matriz.flatten()/np.sum(matriz)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
class_names=['Not Access','Access']
dataframe=pd.DataFrame(matriz,index=class_names, columns=class_names)
sns.heatmap(dataframe, annot=True, fmt='', cmap='Blues')
# Out:
# [[7547  187]
#  [ 554  240]]

# %% [markdown]
# #10.Modelo SVM

# %%
from sklearn.svm import SVC
vectores=SVC()
vectores.fit(x_train, y_train)
y_predic=vectores.predict(x_test)
print("Accuracy: ", accuracy_score(y_test, y_predic)*100, "%")
print("Score training: ",vectores.score(x_train,y_train)*100, "%")
print("Score test: ",vectores.score(x_test,y_test)*100, "%")
# Out:
# Accuracy:  90.75984990619136 %
# Score training:  90.72439975374512 %
# Score test:  90.75984990619136 %

# %% [markdown]
# ##10.1.Matriz de confusión

# %%
from sklearn.metrics import confusion_matrix 
import numpy as np
matriz2=confusion_matrix(y_test,y_predic)
print(matriz2)
import seaborn as sns
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in matriz2.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in matriz2.flatten()/np.sum(matriz2)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
class_names=['Not Access','Access']
dataframe=pd.DataFrame(matriz2,index=class_names, columns=class_names)
sns.heatmap(dataframe, annot=True, fmt='', cmap='Blues')
# Out:
# [[7732    2]
#  [ 786    8]]

# %% [markdown]
# #11.Modelo de KNeighborgs

# %%
from sklearn.neighbors import KNeighborsClassifier
vecino=KNeighborsClassifier(n_neighbors=2)
vecino.fit(x_train, y_train)
y_prediccion=vecino.predict(x_test)
print("Accuracy: ", accuracy_score(y_test, y_predic)*100, "%")
print("Score training: ",vecino.score(x_train,y_train)*100, "%")
print("Score Test: ",vecino.score(x_test,y_test)*100, "%")
# Out:
# Accuracy:  90.75984990619136 %
# Score training:  93.54167277417842 %
# Score Test:  90.2439024390244 %

# %% [markdown]
# ##11.1.Matriz de confusion

# %%
from sklearn.metrics import confusion_matrix 
import numpy as np
matriz3=confusion_matrix(y_test,y_prediccion)
print(matriz3)
import seaborn as sns
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in matriz3.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in matriz3.flatten()/np.sum(matriz3)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
class_names=['Not Access','Access']
dataframe=pd.DataFrame(matriz3,index=class_names, columns=class_names)
sns.heatmap(dataframe, annot=True, fmt='', cmap='Blues')
# Out:
# [[7597  137]
#  [ 695   99]]

# %% [markdown]
# #12.Comparación entre los resultados de todos los modelos

# %% [markdown]
# ![Resultados.PNG](data:image/png;base64,...)

# %% [markdown]
# #13.Conclusiones

# %% [markdown]
# 1.   Según el analisis y estudio realizado al conjunto de datos, se puede concluir que uno de los modelos que más se ajusta para este caso, es el modelo de árbol de clasificación, teniendo en cuenta, que este modelo tiene una presición más alta en comparación a los demas modelos, como se puede evidenciar en la tabla de resultados.
#
# 2.   Sin embargo, los modelos de regresión logistica y KNeighborgs, también podrian ajustarse a este conjunto de datos, aunque su presicion sea un poco más baja en cuanto al árbol de desición, los puntajes obtenidos en cada unos de estos modelos son satisfactorios.
#
# 3.   Teniendo en cuenta el modelo de Super Vector Machine, podemos evidenciar que la precisión de prueba es mayor que la precisión del entrenamiento, lo que hace que el modelo no sea factible en comparación a los demás.
